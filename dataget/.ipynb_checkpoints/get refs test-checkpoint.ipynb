# %%
import sys
from pyhdf.SD import SD, SDC
import numpy as np
import matplotlib.pyplot as plt
import glob
from glob import glob
import os
import requests
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import re
import csv
import h5py
import numpy as np
import json
import datetime
from datetime import timedelta
from dateutil.relativedelta import relativedelta
import functions as f

def download_ref(folder, filename, datestr, MOD_ID, urlprefix):
    username_file = open("/home/fun/profile/modis_username.txt", "r")
    password_file = open("/home/fun/profile/modis_password.txt", "r")
    username = username_file.readline()
    password = password_file.readline()

    url = f.generate_modis_url(datestr, MOD_ID, urlprefix)
    url = url + filename
    if len(filename) == 0:
        filename = 'refer_index_' + MOD_ID + '_' + datestr + '.html'
        print("HTML:", filename)
        
    print ('downloading file ', url)
    
    r = requests.get(url, auth = (username, password))

    if r.status_code == 200:
        print ('writing to', folder + filename)
        if os.path.isfile(folder + filename):
            return 
        with open(folder + filename, 'wb') as out:
            for bits in r.iter_content():
                out.write(bits)    
    
def download_ref_html(folder, MOD_ID, dt, urlprefix):
    profile = folder + 'profile.json'
    file = open(profile)
    info = json.load(file)

    start = datetime.datetime.strptime(info['start'], '%Y-%m-%d')
#         begin_date = start - timedelta(days= int(dt[0:len(dt)-1]))
#         final_date = end + timedelta(days= int(dt[0:len(dt)-1]))

    begin_date = start.replace(year=start.year - 1, month=start.month, day=2)
    it_id = 0
    it_date = begin_date 
    while (it_id < 3): # JH: downdload 12 month of reference images , one for each month
        datestr = it_date.strftime('%Y-%m-%d')
    
        url = f.generate_modis_url(datestr, MOD_ID, urlprefix)
        download_ref(folder, "", datestr, MOD_ID, urlprefix)
        
        if os.path.isfile(folder + 'refer_index_' + MOD_ID + '_' + datestr + '.html'):
            it_date = it_date + relativedelta(months=1)
            it_date = it_date.replace(year=it_date.year, month=it_date.month, day=1)  #JH: always start with first day of month and try
            it_id = it_id + 1
        else:
            it_date = it_date + timedelta(days=1)
        

def download_ref_wrapped(folder, MOD_ID, dt, urlprefix, tiles):
    globprof = folder + 'profile.json'
    print("PROFILE:", globprof)
    with open(globprof) as file:
        prof = json.load(file)
        area = prof['info']['acres_burned']
    if int(area) < 10000:
        return
    
    download_ref_html(folder, MOD_ID, dt, urlprefix)
    f.download_hdf(folder, MOD_ID, urlprefix, tiles, 'refer_index_')

# %%
tiles = [{
    'lat_min': 40,
    'lat_max': 50,
    'name': 'h08v04'
}, 
{
    'lat_min': 30,
    'lat_max': 40,
    'name': 'h08v05'
}]


radius = 25
fillvalue = -3000
wildfires = glob('/home/fun/wildfire_data/Erskine_Fire_2016-06-23')

for wildfire in wildfires:
    download_ref_wrapped(wildfire + '/', 'MOD13Q1.006', '32d', 'https://e4ftl01.cr.usgs.gov/MOLT/', tiles)
    f.write_imgs(wildfire, radius, fillvalue, tiles)
# Out:
# PROFILE: /home/fun/wildfire_data/Erskine_Fire_2016-06-23/profile.json
# DATESTR: 2015-06-02 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.02/
# HTML: ref_index_MOD13Q1.006_2015-6-2.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.02/
# STATUS 404
# DATESTR: 2015-06-03 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.03/
# HTML: ref_index_MOD13Q1.006_2015-6-3.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.03/
# STATUS 404
# DATESTR: 2015-06-04 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.04/
# HTML: ref_index_MOD13Q1.006_2015-6-4.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.04/
# STATUS 404
# DATESTR: 2015-06-05 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.05/
# HTML: ref_index_MOD13Q1.006_2015-6-5.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.05/
# STATUS 404
# DATESTR: 2015-06-06 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.06/
# HTML: ref_index_MOD13Q1.006_2015-6-6.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.06/
# STATUS 404
# DATESTR: 2015-06-07 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.07/
# HTML: ref_index_MOD13Q1.006_2015-6-7.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.07/
# STATUS 404
# DATESTR: 2015-06-08 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.08/
# HTML: ref_index_MOD13Q1.006_2015-6-8.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.08/
# STATUS 404
# DATESTR: 2015-06-09 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.09/
# HTML: ref_index_MOD13Q1.006_2015-6-9.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.09/
# STATUS 404
# DATESTR: 2015-06-10 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.10/
# HTML: ref_index_MOD13Q1.006_2015-6-10.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.10/
# STATUS 200
# writing to /home/fun/wildfire_data/Erskine_Fire_2016-06-23/ref_index_MOD13Q1.006_2015-6-10.html
# DATESTR: 2015-07-01 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.01/
# HTML: ref_index_MOD13Q1.006_2015-7-1.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.01/
# STATUS 404
# DATESTR: 2015-07-02 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.02/
# HTML: ref_index_MOD13Q1.006_2015-7-2.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.02/
# STATUS 404
# DATESTR: 2015-07-03 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.03/
# HTML: ref_index_MOD13Q1.006_2015-7-3.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.03/
# STATUS 404
# DATESTR: 2015-07-04 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.04/
# HTML: ref_index_MOD13Q1.006_2015-7-4.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.04/
# STATUS 404
# DATESTR: 2015-07-05 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.05/
# HTML: ref_index_MOD13Q1.006_2015-7-5.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.05/
# STATUS 404
# DATESTR: 2015-07-06 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.06/
# HTML: ref_index_MOD13Q1.006_2015-7-6.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.06/
# STATUS 404
# DATESTR: 2015-07-07 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.07/
# HTML: ref_index_MOD13Q1.006_2015-7-7.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.07/
# STATUS 404
# DATESTR: 2015-07-08 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.08/
# HTML: ref_index_MOD13Q1.006_2015-7-8.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.08/
# STATUS 404
# DATESTR: 2015-07-09 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.09/
# HTML: ref_index_MOD13Q1.006_2015-7-9.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.09/
# STATUS 404
# DATESTR: 2015-07-10 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.10/
# HTML: ref_index_MOD13Q1.006_2015-7-10.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.10/
# STATUS 404
# DATESTR: 2015-07-11 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.11/
# HTML: ref_index_MOD13Q1.006_2015-7-11.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.11/
# STATUS 404
# DATESTR: 2015-07-12 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.12/
# HTML: ref_index_MOD13Q1.006_2015-7-12.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.12/
# STATUS 200
# writing to /home/fun/wildfire_data/Erskine_Fire_2016-06-23/ref_index_MOD13Q1.006_2015-7-12.html
# DATESTR: 2015-08-01 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.01/
# HTML: ref_index_MOD13Q1.006_2015-8-1.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.01/
# STATUS 404
# DATESTR: 2015-08-02 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.02/
# HTML: ref_index_MOD13Q1.006_2015-8-2.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.02/
# STATUS 404
# DATESTR: 2015-08-03 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.03/
# HTML: ref_index_MOD13Q1.006_2015-8-3.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.03/
# STATUS 404
# DATESTR: 2015-08-04 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.04/
# HTML: ref_index_MOD13Q1.006_2015-8-4.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.04/
# STATUS 404
# DATESTR: 2015-08-05 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.05/
# HTML: ref_index_MOD13Q1.006_2015-8-5.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.05/
# STATUS 404
# DATESTR: 2015-08-06 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.06/
# HTML: ref_index_MOD13Q1.006_2015-8-6.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.06/
# STATUS 404
# DATESTR: 2015-08-07 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.07/
# HTML: ref_index_MOD13Q1.006_2015-8-7.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.07/
# STATUS 404
# DATESTR: 2015-08-08 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.08/
# HTML: ref_index_MOD13Q1.006_2015-8-8.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.08/
# STATUS 404
# DATESTR: 2015-08-09 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.09/
# HTML: ref_index_MOD13Q1.006_2015-8-9.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.09/
# STATUS 404
# DATESTR: 2015-08-10 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.10/
# HTML: ref_index_MOD13Q1.006_2015-8-10.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.10/
# STATUS 404
# DATESTR: 2015-08-11 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.11/
# HTML: ref_index_MOD13Q1.006_2015-8-11.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.11/
# STATUS 404
# DATESTR: 2015-08-12 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.12/
# HTML: ref_index_MOD13Q1.006_2015-8-12.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.12/
# STATUS 404
# DATESTR: 2015-08-13 00:00:00
# FILENAME:
# https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.13/
# HTML: ref_index_MOD13Q1.006_2015-8-13.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.13/
# STATUS 200
# writing to /home/fun/wildfire_data/Erskine_Fire_2016-06-23/ref_index_MOD13Q1.006_2015-8-13.html
# parsing /home/fun/wildfire_data/Erskine_Fire_2016-06-23/ref_index_MOD13Q1.006_2015-6-10.html
# downloading  MOD13Q1.A2015161.h08v05.006.2015301071947.hdf to  /home/fun/wildfire_data/Erskine_Fire_2016-06-23/
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/_201.-6.10/MOD13Q1.A2015161.h08v05.006.2015301071947.hdf
# parsing /home/fun/wildfire_data/Erskine_Fire_2016-06-23/ref_index_MOD13Q1.006_2015-7-12.html
# downloading  MOD13Q1.A2015193.h08v05.006.2015304005554.hdf to  /home/fun/wildfire_data/Erskine_Fire_2016-06-23/
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/_201.-7.12/MOD13Q1.A2015193.h08v05.006.2015304005554.hdf
# parsing /home/fun/wildfire_data/Erskine_Fire_2016-06-23/ref_index_MOD13Q1.006_2015-8-13.html
# downloading  MOD13Q1.A2015225.h08v05.006.2015305195636.hdf to  /home/fun/wildfire_data/Erskine_Fire_2016-06-23/
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/_201.-8.13/MOD13Q1.A2015225.h08v05.006.2015305195636.hdf
# ALL FILES: []

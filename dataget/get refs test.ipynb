# %%
import sys
from pyhdf.SD import SD, SDC
import numpy as np
import matplotlib.pyplot as plt
import glob
from glob import glob
import os
import requests
from urllib.parse import urlparse
from bs4 import BeautifulSoup
import re
import csv
import h5py
import numpy as np
import json
import datetime
from datetime import timedelta
from dateutil.relativedelta import relativedelta
import functions as f

def download_ref(folder, filename, datestr, MOD_ID, urlprefix):
    username_file = open("/home/fun/profile/modis_username.txt", "r")
    password_file = open("/home/fun/profile/modis_password.txt", "r")
    username = username_file.readline()
    password = password_file.readline()

    url = f.generate_modis_url(datestr, MOD_ID, urlprefix)
    url = url + filename
    if len(filename) == 0:
        filename = 'refer_index_' + MOD_ID + '_' + datestr + '.html'
        print("HTML:", filename)
        
    print ('downloading file ', url)
    
    r = requests.get(url, auth = (username, password))

    if r.status_code == 200:
        print ('writing to', folder + filename)
        if os.path.isfile(folder + filename):
            return 
        with open(folder + filename, 'wb') as out:
            for bits in r.iter_content():
                out.write(bits)    
    
def download_ref_html(folder, MOD_ID, dt, urlprefix):
    profile = folder + 'profile.json'
    file = open(profile)
    info = json.load(file)

    start = datetime.datetime.strptime(info['start'], '%Y-%m-%d')
#         begin_date = start - timedelta(days= int(dt[0:len(dt)-1]))
#         final_date = end + timedelta(days= int(dt[0:len(dt)-1]))

    begin_date = start.replace(year=start.year - 1, month=start.month, day=2)
    it_id = 0
    it_date = begin_date 
    while (it_id < 12): # JH: downdload 12 month of reference images , one for each month
        datestr = it_date.strftime('%Y-%m-%d')
    
        url = f.generate_modis_url(datestr, MOD_ID, urlprefix)
        download_ref(folder, "", datestr, MOD_ID, urlprefix)
        
        if os.path.isfile(folder + 'refer_index_' + MOD_ID + '_' + datestr + '.html'):
            it_date = it_date + relativedelta(months=1)
            it_date = it_date.replace(year=it_date.year, month=it_date.month, day=1)  #JH: always start with first day of month and try
            it_id = it_id + 1
        else:
            it_date = it_date + timedelta(days=1)
        

def download_ref_wrapped(folder, MOD_ID, dt, urlprefix, tiles):
    globprof = folder + 'profile.json'
    print("PROFILE:", globprof)
    with open(globprof) as file:
        prof = json.load(file)
        area = prof['info']['acres_burned']
    if int(area) < 10000:
        return
    
    download_ref_html(folder, MOD_ID, dt, urlprefix)
    f.download_hdf(folder, MOD_ID, urlprefix, tiles, 'refer_index_')

# %%
tiles = [{
    'lat_min': 40,
    'lat_max': 50,
    'name': 'h08v04'
}, 
{
    'lat_min': 30,
    'lat_max': 40,
    'name': 'h08v05'
}]


radius = 25
fillvalue = -3000
wildfires = glob('/home/fun/wildfire_data/Erskine_Fire_2016-06-23')

for wildfire in wildfires:
    download_ref_wrapped(wildfire + '/', 'MOD13Q1.006', '32d', 'https://e4ftl01.cr.usgs.gov/MOLT/', tiles)
    f.write_imgs(wildfire, radius, fillvalue, tiles)
# Out:
# PROFILE: /home/fun/wildfire_data/Erskine_Fire_2016-06-23/profile.json
# HTML: refer_index_MOD13Q1.006_2015-06-02.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.02/
# HTML: refer_index_MOD13Q1.006_2015-06-03.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.03/
# HTML: refer_index_MOD13Q1.006_2015-06-04.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.04/
# HTML: refer_index_MOD13Q1.006_2015-06-05.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.05/
# HTML: refer_index_MOD13Q1.006_2015-06-06.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.06/
# HTML: refer_index_MOD13Q1.006_2015-06-07.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.07/
# HTML: refer_index_MOD13Q1.006_2015-06-08.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.08/
# HTML: refer_index_MOD13Q1.006_2015-06-09.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.09/
# HTML: refer_index_MOD13Q1.006_2015-06-10.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.06.10/
# writing to /home/fun/wildfire_data/Erskine_Fire_2016-06-23/refer_index_MOD13Q1.006_2015-06-10.html
# HTML: refer_index_MOD13Q1.006_2015-07-01.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.01/
# HTML: refer_index_MOD13Q1.006_2015-07-02.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.02/
# HTML: refer_index_MOD13Q1.006_2015-07-03.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.03/
# HTML: refer_index_MOD13Q1.006_2015-07-04.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.04/
# HTML: refer_index_MOD13Q1.006_2015-07-05.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.05/
# HTML: refer_index_MOD13Q1.006_2015-07-06.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.06/
# HTML: refer_index_MOD13Q1.006_2015-07-07.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.07/
# HTML: refer_index_MOD13Q1.006_2015-07-08.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.08/
# HTML: refer_index_MOD13Q1.006_2015-07-09.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.09/
# HTML: refer_index_MOD13Q1.006_2015-07-10.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.10/
# HTML: refer_index_MOD13Q1.006_2015-07-11.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.11/
# HTML: refer_index_MOD13Q1.006_2015-07-12.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.12/
# writing to /home/fun/wildfire_data/Erskine_Fire_2016-06-23/refer_index_MOD13Q1.006_2015-07-12.html
# HTML: refer_index_MOD13Q1.006_2015-08-01.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.01/
# HTML: refer_index_MOD13Q1.006_2015-08-02.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.02/
# HTML: refer_index_MOD13Q1.006_2015-08-03.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.03/
# HTML: refer_index_MOD13Q1.006_2015-08-04.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.04/
# HTML: refer_index_MOD13Q1.006_2015-08-05.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.05/
# HTML: refer_index_MOD13Q1.006_2015-08-06.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.06/
# HTML: refer_index_MOD13Q1.006_2015-08-07.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.07/
# HTML: refer_index_MOD13Q1.006_2015-08-08.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.08/
# HTML: refer_index_MOD13Q1.006_2015-08-09.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.09/
# HTML: refer_index_MOD13Q1.006_2015-08-10.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.10/
# HTML: refer_index_MOD13Q1.006_2015-08-11.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.11/
# HTML: refer_index_MOD13Q1.006_2015-08-12.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.12/
# HTML: refer_index_MOD13Q1.006_2015-08-13.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.08.13/
# writing to /home/fun/wildfire_data/Erskine_Fire_2016-06-23/refer_index_MOD13Q1.006_2015-08-13.html
# HTML: refer_index_MOD13Q1.006_2015-09-01.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.09.01/
# HTML: refer_index_MOD13Q1.006_2015-09-02.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.09.02/
# HTML: refer_index_MOD13Q1.006_2015-09-03.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.09.03/
# HTML: refer_index_MOD13Q1.006_2015-09-04.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.09.04/
# HTML: refer_index_MOD13Q1.006_2015-09-05.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.09.05/
# HTML: refer_index_MOD13Q1.006_2015-09-06.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.09.06/
# HTML: refer_index_MOD13Q1.006_2015-09-07.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.09.07/
# HTML: refer_index_MOD13Q1.006_2015-09-08.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.09.08/
# HTML: refer_index_MOD13Q1.006_2015-09-09.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.09.09/
# HTML: refer_index_MOD13Q1.006_2015-09-10.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.09.10/
# HTML: refer_index_MOD13Q1.006_2015-09-11.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.09.11/
# HTML: refer_index_MOD13Q1.006_2015-09-12.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.09.12/
# HTML: refer_index_MOD13Q1.006_2015-09-13.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.09.13/
# HTML: refer_index_MOD13Q1.006_2015-09-14.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.09.14/
# writing to /home/fun/wildfire_data/Erskine_Fire_2016-06-23/refer_index_MOD13Q1.006_2015-09-14.html
# HTML: refer_index_MOD13Q1.006_2015-10-01.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.10.01/
# HTML: refer_index_MOD13Q1.006_2015-10-02.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.10.02/
# HTML: refer_index_MOD13Q1.006_2015-10-03.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.10.03/
# HTML: refer_index_MOD13Q1.006_2015-10-04.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.10.04/
# HTML: refer_index_MOD13Q1.006_2015-10-05.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.10.05/
# HTML: refer_index_MOD13Q1.006_2015-10-06.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.10.06/
# HTML: refer_index_MOD13Q1.006_2015-10-07.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.10.07/
# HTML: refer_index_MOD13Q1.006_2015-10-08.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.10.08/
# HTML: refer_index_MOD13Q1.006_2015-10-09.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.10.09/
# HTML: refer_index_MOD13Q1.006_2015-10-10.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.10.10/
# HTML: refer_index_MOD13Q1.006_2015-10-11.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.10.11/
# HTML: refer_index_MOD13Q1.006_2015-10-12.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.10.12/
# HTML: refer_index_MOD13Q1.006_2015-10-13.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.10.13/
# HTML: refer_index_MOD13Q1.006_2015-10-14.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.10.14/
# HTML: refer_index_MOD13Q1.006_2015-10-15.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.10.15/
# HTML: refer_index_MOD13Q1.006_2015-10-16.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.10.16/
# writing to /home/fun/wildfire_data/Erskine_Fire_2016-06-23/refer_index_MOD13Q1.006_2015-10-16.html
# HTML: refer_index_MOD13Q1.006_2015-11-01.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.11.01/
# writing to /home/fun/wildfire_data/Erskine_Fire_2016-06-23/refer_index_MOD13Q1.006_2015-11-01.html
# HTML: refer_index_MOD13Q1.006_2015-12-01.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.12.01/
# HTML: refer_index_MOD13Q1.006_2015-12-02.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.12.02/
# HTML: refer_index_MOD13Q1.006_2015-12-03.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.12.03/
# writing to /home/fun/wildfire_data/Erskine_Fire_2016-06-23/refer_index_MOD13Q1.006_2015-12-03.html
# HTML: refer_index_MOD13Q1.006_2016-01-01.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.01.01/
# writing to /home/fun/wildfire_data/Erskine_Fire_2016-06-23/refer_index_MOD13Q1.006_2016-01-01.html
# HTML: refer_index_MOD13Q1.006_2016-02-01.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.02.01/
# HTML: refer_index_MOD13Q1.006_2016-02-02.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.02.02/
# writing to /home/fun/wildfire_data/Erskine_Fire_2016-06-23/refer_index_MOD13Q1.006_2016-02-02.html
# HTML: refer_index_MOD13Q1.006_2016-03-01.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.03.01/
# HTML: refer_index_MOD13Q1.006_2016-03-02.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.03.02/
# HTML: refer_index_MOD13Q1.006_2016-03-03.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.03.03/
# HTML: refer_index_MOD13Q1.006_2016-03-04.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.03.04/
# HTML: refer_index_MOD13Q1.006_2016-03-05.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.03.05/
# writing to /home/fun/wildfire_data/Erskine_Fire_2016-06-23/refer_index_MOD13Q1.006_2016-03-05.html
# HTML: refer_index_MOD13Q1.006_2016-04-01.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.04.01/
# HTML: refer_index_MOD13Q1.006_2016-04-02.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.04.02/
# HTML: refer_index_MOD13Q1.006_2016-04-03.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.04.03/
# HTML: refer_index_MOD13Q1.006_2016-04-04.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.04.04/
# HTML: refer_index_MOD13Q1.006_2016-04-05.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.04.05/
# HTML: refer_index_MOD13Q1.006_2016-04-06.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.04.06/
# writing to /home/fun/wildfire_data/Erskine_Fire_2016-06-23/refer_index_MOD13Q1.006_2016-04-06.html
# HTML: refer_index_MOD13Q1.006_2016-05-01.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.05.01/
# HTML: refer_index_MOD13Q1.006_2016-05-02.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.05.02/
# HTML: refer_index_MOD13Q1.006_2016-05-03.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.05.03/
# HTML: refer_index_MOD13Q1.006_2016-05-04.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.05.04/
# HTML: refer_index_MOD13Q1.006_2016-05-05.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.05.05/
# HTML: refer_index_MOD13Q1.006_2016-05-06.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.05.06/
# HTML: refer_index_MOD13Q1.006_2016-05-07.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.05.07/
# HTML: refer_index_MOD13Q1.006_2016-05-08.html
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.05.08/
# writing to /home/fun/wildfire_data/Erskine_Fire_2016-06-23/refer_index_MOD13Q1.006_2016-05-08.html
# parsing /home/fun/wildfire_data/Erskine_Fire_2016-06-23/refer_index_MOD13Q1.006_2016-03-05.html
# downloading  MOD13Q1.A2016065.h08v05.006.2016111112501.hdf to  /home/fun/wildfire_data/Erskine_Fire_2016-06-23/
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2016.03.05/MOD13Q1.A2016065.h08v05.006.2016111112501.hdf
# writing to /home/fun/wildfire_data/Erskine_Fire_2016-06-23/MOD13Q1.A2016065.h08v05.006.2016111112501.hdf
# parsing /home/fun/wildfire_data/Erskine_Fire_2016-06-23/refer_index_MOD13Q1.006_2015-07-12.html
# downloading  MOD13Q1.A2015193.h08v05.006.2015304005554.hdf to  /home/fun/wildfire_data/Erskine_Fire_2016-06-23/
# downloading file  https://e4ftl01.cr.usgs.gov/MOLT/MOD13Q1.006/2015.07.12/MOD13Q1.A2015193.h08v05.006.2015304005554.hdf

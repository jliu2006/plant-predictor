# %%
import requests
import urllib
import pandas as pd
import glob
import time
# USGS Elevation Point Query Service
#url = r'https://nationalmap.gov/epqs/pqs.php?'
#new 2023:
url = r'https://epqs.nationalmap.gov/v1/json?'

# coordinates with known elevation 
lat =   49.999
lon =  -155.567
   

def elevation_function(lon, lat):
                
        # define rest query params
        params = {
            'output': 'json',
            'x': lon,
            'y': lat,
            'units': 'Meters'
        }
        
        print (params)
        # format query string and return query value
        result = requests.get((url + urllib.parse.urlencode(params)))
        #elevations.append(result.json()['USGS_Elevation_Point_Query_Service']['Elevation_Query']['Elevation'])
        #new 2023:
       
        try:
            return result.json()['value']
        except:
            return 0

    

print (elevation_function(lon, lat))
# Out:
# {'output': 'json', 'x': 49.999, 'y': -155.567, 'units': 'Meters'}
# 0

# %%
coordnates_path = '/home/fun/wildfire_coords'

modtypes = ['MOD13Q1'] 
keys = ['h08v04']

h08v04_info = dict([
    ('ll_lon', -131.0149),
    ('ll_lat', 39.7081),
    ('ul_lon', -156.8405),
    ('ul_lat', 49.8983),
    ('ur_lon', -140.2398),
    ('ur_lat', 50.1258),
    ('lr_lon', -117.2848),
    ('lr_lat', 39.8699),
    ('lat_delta', 10),
    ('lat_min', 40),
    ('lat_max', 50),
])



for mod in modtypes:
    for key in keys:
        coords_files = glob.glob(coordnates_path + '/*' + mod + '*' + key +'*')
        lats = []
        lons = []
        elevations = []
        for it in coords_files:
            if 'lat' in it:
                with open(it, 'r') as f:
                    lats = f.readlines()
            if 'lon' in it:
                with open(it, 'r') as f:
                    lons = f.readlines()
                    
        for i in range(0, len(lats)):
            if (lats[i] == '\n'):
                elevations.append('\n')
            else:
                lon = float(lons[i].strip(', \n'))
                lat = float(lats[i].strip(', \n'))
                
                if lon < h08v04_info['ll_lon'] or lon > h08v04_info['lr_lon'] \
                    or lat < h08v04_info['ll_lat'] or lat > h08v04_info['ur_lat']:
                    elevations.append('0\n')
                else:
                    v = elevation_function(lon, lat)
                    print (v)
                    elevations.append(str(v) + '\n')
                    if (i % 10000 ) == 0 and i > 0:
                        time.sleep(1)
                    
            
                
                
        
        filename = coordnates_path + '/' + mod + "_" + key + '_elevation.txt'
        file = open(filename,'w')
        file.writelines(elevations)
        file.close()
# Out:
# {'output': 'json', 'x': 46.6094, 'y': -131.012, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.6073, 'y': -131.013, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.6073, 'y': -131.01, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.6073, 'y': -131.007, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.6052, 'y': -131.014, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.6052, 'y': -131.011, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.6052, 'y': -131.008, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.6052, 'y': -131.005, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.6052, 'y': -131.002, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.6031, 'y': -131.012, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.6031, 'y': -131.009, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.6031, 'y': -131.006, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.6031, 'y': -131.003, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.6031, 'y': -131.0, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.6031, 'y': -130.997, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.601, 'y': -131.013, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.601, 'y': -131.01, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.601, 'y': -131.007, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.601, 'y': -131.004, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.601, 'y': -131.001, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.601, 'y': -130.998, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.601, 'y': -130.995, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.601, 'y': -130.992, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.599, 'y': -131.014, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.599, 'y': -131.011, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.599, 'y': -131.008, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.599, 'y': -131.005, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.599, 'y': -131.002, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.599, 'y': -130.999, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.599, 'y': -130.996, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.599, 'y': -130.993, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.599, 'y': -130.99, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.599, 'y': -130.987, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5969, 'y': -131.012, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5969, 'y': -131.009, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5969, 'y': -131.006, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5969, 'y': -131.003, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5969, 'y': -131.0, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5969, 'y': -130.997, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5969, 'y': -130.994, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5969, 'y': -130.991, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5969, 'y': -130.988, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5969, 'y': -130.985, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5969, 'y': -130.982, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5948, 'y': -131.013, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5948, 'y': -131.01, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5948, 'y': -131.007, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5948, 'y': -131.004, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5948, 'y': -131.001, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5948, 'y': -130.998, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5948, 'y': -130.995, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5948, 'y': -130.992, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5948, 'y': -130.989, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5948, 'y': -130.986, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5948, 'y': -130.983, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5948, 'y': -130.98, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5948, 'y': -130.977, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5927, 'y': -131.014, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5927, 'y': -131.011, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5927, 'y': -131.008, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5927, 'y': -131.005, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5927, 'y': -131.002, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5927, 'y': -130.999, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5927, 'y': -130.996, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5927, 'y': -130.993, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5927, 'y': -130.99, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5927, 'y': -130.987, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5927, 'y': -130.984, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5927, 'y': -130.981, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5927, 'y': -130.978, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5927, 'y': -130.975, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5927, 'y': -130.972, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5906, 'y': -131.012, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5906, 'y': -131.009, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5906, 'y': -131.006, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5906, 'y': -131.003, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5906, 'y': -131.0, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5906, 'y': -130.997, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5906, 'y': -130.994, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5906, 'y': -130.991, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5906, 'y': -130.988, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5906, 'y': -130.985, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5906, 'y': -130.982, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5906, 'y': -130.979, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5906, 'y': -130.976, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5906, 'y': -130.973, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5906, 'y': -130.97, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5906, 'y': -130.967, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5885, 'y': -131.013, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5885, 'y': -131.01, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5885, 'y': -131.007, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5885, 'y': -131.004, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5885, 'y': -131.001, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5885, 'y': -130.998, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5885, 'y': -130.995, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5885, 'y': -130.992, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5885, 'y': -130.989, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5885, 'y': -130.986, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5885, 'y': -130.983, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5885, 'y': -130.98, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5885, 'y': -130.977, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5885, 'y': -130.974, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5885, 'y': -130.971, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5885, 'y': -130.968, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5885, 'y': -130.965, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5885, 'y': -130.962, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5865, 'y': -131.014, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5865, 'y': -131.011, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5865, 'y': -131.008, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5865, 'y': -131.005, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5865, 'y': -131.002, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5865, 'y': -130.999, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5865, 'y': -130.996, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5865, 'y': -130.993, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5865, 'y': -130.99, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5865, 'y': -130.987, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5865, 'y': -130.984, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5865, 'y': -130.981, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5865, 'y': -130.978, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5865, 'y': -130.975, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5865, 'y': -130.972, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5865, 'y': -130.969, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5865, 'y': -130.966, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5865, 'y': -130.963, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5865, 'y': -130.96, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5865, 'y': -130.956, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -131.012, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -131.009, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -131.006, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -131.003, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -131.0, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -130.997, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -130.994, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -130.991, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -130.988, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -130.985, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -130.982, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -130.979, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -130.976, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -130.973, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -130.97, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -130.967, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -130.964, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -130.961, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -130.958, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -130.954, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5844, 'y': -130.951, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -131.013, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -131.01, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -131.007, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -131.004, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -131.001, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -130.998, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -130.995, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -130.992, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -130.989, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -130.986, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -130.983, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -130.98, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -130.977, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -130.974, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -130.971, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -130.968, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -130.965, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -130.962, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -130.959, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -130.955, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -130.952, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -130.949, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5823, 'y': -130.946, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -131.014, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -131.011, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -131.008, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -131.005, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -131.002, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -130.999, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -130.996, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -130.993, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -130.99, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -130.987, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -130.984, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -130.981, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -130.978, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -130.975, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -130.972, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -130.969, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -130.966, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -130.963, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -130.96, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -130.957, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -130.953, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -130.95, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -130.947, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -130.944, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5802, 'y': -130.941, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -131.012, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -131.009, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -131.006, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -131.003, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -131.0, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.997, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.994, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.991, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.988, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.985, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.982, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.979, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.976, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.973, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.97, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.967, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.964, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.961, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.958, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.955, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.951, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.948, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.945, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.942, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.939, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5781, 'y': -130.936, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -131.013, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -131.01, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -131.007, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -131.004, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -131.001, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.998, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.995, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.992, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.989, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.986, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.983, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.98, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.977, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.974, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.971, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.968, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.965, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.962, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.959, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.956, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.953, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.949, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.946, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.943, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.94, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.937, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.934, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.576, 'y': -130.931, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -131.014, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -131.011, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -131.008, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -131.005, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -131.002, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.999, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.996, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.993, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.99, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.987, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.984, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.981, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.978, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.975, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.972, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.969, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.966, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.963, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.96, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.957, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.954, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.951, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.947, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.944, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.941, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.938, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.935, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.932, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.929, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.574, 'y': -130.926, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -131.012, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -131.009, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -131.006, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -131.003, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -131.0, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.997, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.994, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.991, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.988, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.985, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.982, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.979, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.976, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.973, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.97, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.967, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.964, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.961, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.958, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.955, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.952, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.949, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.945, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.942, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.939, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.936, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.933, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.93, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.927, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.924, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5719, 'y': -130.921, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -131.013, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -131.01, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -131.007, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -131.004, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -131.001, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.998, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.995, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.992, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.989, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.986, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.983, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.98, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.977, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.974, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.971, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.968, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.965, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.962, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.959, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.956, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.953, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.95, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.947, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.943, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.94, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.937, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.934, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.931, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.928, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.925, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.922, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.919, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5698, 'y': -130.916, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -131.014, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -131.011, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -131.008, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -131.005, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -131.002, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.999, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.996, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.993, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.99, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.987, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.984, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.981, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.978, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.975, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.972, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.969, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.966, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.963, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.96, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.957, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.954, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.951, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.948, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.945, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.942, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.938, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.935, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.932, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.929, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.926, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.923, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.92, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.917, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.914, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5677, 'y': -130.911, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -131.012, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -131.009, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -131.006, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -131.003, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -131.0, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.997, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.994, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.991, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.988, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.985, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.982, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.979, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.976, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.973, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.97, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.967, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.964, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.961, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.958, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.955, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.952, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.949, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.946, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.943, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.94, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.936, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.933, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.93, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.927, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.924, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.921, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.918, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.915, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.912, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.909, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5656, 'y': -130.906, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -131.013, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -131.01, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -131.007, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -131.004, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -131.001, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.998, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.995, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.992, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.989, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.986, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.983, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.98, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.977, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.974, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.971, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.968, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.965, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.962, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.959, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.956, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.953, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.95, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.947, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.944, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.941, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.938, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.934, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.931, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.928, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.925, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.922, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.919, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.916, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.913, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.91, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.907, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.904, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5635, 'y': -130.901, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -131.014, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -131.011, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -131.008, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -131.005, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -131.002, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.999, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.996, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.993, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.99, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.987, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.984, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.981, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.978, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.975, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.972, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.969, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.966, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.963, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.96, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.957, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.954, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.951, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.948, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.945, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.942, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.939, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.936, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.932, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.929, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.926, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.923, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.92, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.917, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.914, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.911, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.908, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.905, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.902, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.899, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5615, 'y': -130.896, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -131.012, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -131.009, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -131.006, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -131.003, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -131.0, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.997, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.994, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.991, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.988, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.985, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.982, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.979, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.976, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.973, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.97, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.967, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.964, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.961, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.958, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.955, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.952, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.949, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.946, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.943, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.94, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.937, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.934, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.93, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.927, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.924, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.921, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.918, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.915, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.912, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.909, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.906, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.903, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.9, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.897, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.894, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5594, 'y': -130.891, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -131.013, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -131.01, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -131.007, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -131.004, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -131.001, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.998, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.995, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.992, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.989, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.986, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.983, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.98, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.977, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.974, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.971, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.968, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.965, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.962, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.959, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.956, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.953, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.95, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.947, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.944, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.941, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.938, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.935, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.932, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.928, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.925, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.922, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.919, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.916, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.913, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.91, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.907, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.904, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.901, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.898, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.895, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.892, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.889, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5573, 'y': -130.886, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -131.014, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -131.011, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -131.008, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -131.005, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -131.002, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.999, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.996, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.993, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.99, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.987, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.984, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.981, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.978, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.975, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.972, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.969, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.966, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.963, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.96, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.957, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.954, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.951, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.948, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.945, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.942, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.939, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.936, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.933, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.93, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.926, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.923, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.92, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.917, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.914, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.911, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.908, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.905, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.902, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.899, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.896, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.893, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.89, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.887, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.884, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5552, 'y': -130.881, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -131.012, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -131.009, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -131.006, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -131.003, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -131.0, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.997, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.994, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.991, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.988, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.985, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.982, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.979, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.976, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.973, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.97, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.967, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.964, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.961, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.958, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.955, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.952, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.949, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.946, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.943, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.94, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.937, 'units': 'Meters'}
# 0
# {'output': 'json', 'x': 46.5531, 'y': -130.934, 'units': 'Meters'}

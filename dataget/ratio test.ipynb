# %%
import sys
import os
import glob
from glob import glob
import numpy as np
import datetime
import matplotlib.pyplot as plt
import json

# %%
def get_ratio(folder): # 0 is NDVI, 1 is EVI
    raw_ndvi = folder + '/MOD13Q1*.npy'
    ref_ndvi = folder + '/r_MOD13Q1*.npy'
    ndvi_arrs = glob(raw_ndvi)
    ndvi_arrs.sort()
    ndvi_refs = glob(ref_ndvi)
    ndvi_refs.sort()
    
    for it in ndvi_arrs:
        print("CURRENT:", it)
        month = it[-10:-6] # -xx-
        date = it[-14:-4]
        print("MONTH:", month)
        it_ref = [k for k in ndvi_refs if month in k]
        ndvi_arr = np.load(it)
        ndvi_ref = np.load(it_ref[0])
        
        res = np.zeros(shape=(ndvi_arr.shape))
        
        for layer in range(len(ndvi_arr)):
            for i in range(len(ndvi_arr[0])):
                for j in range(len(ndvi_arr[0])):
                    if (ndvi_arr[layer][i][j] <= 0) or (ndvi_ref[layer][i][j] <= 0):
                        res[layer][i][j] = 0
                    else:
                        res[layer][i][j] = round(ndvi_arr[layer][i][j] / ndvi_ref[layer][i][j], 2)
        
        resfile = folder + '/ratio_MOD13Q1_' + date + '.npy'
        np.save(resfile, res)

# %%
folders = glob('/home/fun/wildfire_data/Zogg_Fire_2020-09-27')

for folder in folders:
    prof = folder + '/profile.json'
    f = open(prof)
    info = json.load(f)
    end = datetime.datetime.strptime(info['end'], '%Y-%m-%d')
    cutoff_date = end.replace(year=2021, month=2, day=1)
    if(info['info']['acres_burned'] >= 10000) and (end <= cutoff_date):
        get_ratio(folder)
# Out:
# CURRENT: /home/fun/wildfire_data/Zogg_Fire_2020-09-27/MOD13Q1_2019-09-14.npy
# MONTH: -09-
# CURRENT: /home/fun/wildfire_data/Zogg_Fire_2020-09-27/MOD13Q1_2019-10-16.npy
# MONTH: -10-
# CURRENT: /home/fun/wildfire_data/Zogg_Fire_2020-09-27/MOD13Q1_2019-11-01.npy
# MONTH: -11-
# CURRENT: /home/fun/wildfire_data/Zogg_Fire_2020-09-27/MOD13Q1_2019-12-03.npy
# MONTH: -12-
# CURRENT: /home/fun/wildfire_data/Zogg_Fire_2020-09-27/MOD13Q1_2020-01-01.npy
# MONTH: -01-
# CURRENT: /home/fun/wildfire_data/Zogg_Fire_2020-09-27/MOD13Q1_2020-02-02.npy
# MONTH: -02-
# CURRENT: /home/fun/wildfire_data/Zogg_Fire_2020-09-27/MOD13Q1_2020-03-05.npy
# MONTH: -03-
# CURRENT: /home/fun/wildfire_data/Zogg_Fire_2020-09-27/MOD13Q1_2020-04-06.npy
# MONTH: -04-
# CURRENT: /home/fun/wildfire_data/Zogg_Fire_2020-09-27/MOD13Q1_2020-05-08.npy
# MONTH: -05-
# CURRENT: /home/fun/wildfire_data/Zogg_Fire_2020-09-27/MOD13Q1_2020-06-09.npy
# MONTH: -06-
# CURRENT: /home/fun/wildfire_data/Zogg_Fire_2020-09-27/MOD13Q1_2020-07-11.npy
# MONTH: -07-
# CURRENT: /home/fun/wildfire_data/Zogg_Fire_2020-09-27/MOD13Q1_2020-07-27.npy
# MONTH: -07-
